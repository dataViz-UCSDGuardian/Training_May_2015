# %%
twoD = []
for rows in range(0,5):        
    twoD.append([1,2,3])
    
print(twoD)
# Out:
# [[1, 2, 3], [1, 2, 3], [1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
import openpyxl

book = openpyxl.load_workbook('finance_and_giving.xlsx' )

sheet1 = book.get_sheet_by_name("12.1.1")
sheet2 = book.get_sheet_by_name("12.1.2")

print (sheet1.cell(row=4,column=2).value)
print(sheet1['B4'].value)
# Out:
# Grants and Contracts
# Grants and Contracts

# %%
array = []
for i in range(2,13):
    array.append([])
    for j in range(4,15):
        sheet1.cell(row=i, column=j).value
        #print(i, j, sheet1.cell(row=1, column = j).value)
        array[i-2].append([sheet1.cell(row=i, column=j).value])
        
print (array)
# Out:
# [[['03-04'], ['04-05'], ['05-06'], ['06-07'], ['07-08'], ['08-09'], ['09-10'], ['10-11'], ['11-12'], ['12-13'], ['13-14']], [[4703855.533015959], [4928878.667136051], [5043921.031657308], [5230971.695794392], [5504645.074718722], [5932930.543677559], [6389456.172786481], [7015898.718810212], [7084958.547740217], [7540238.586382454], [8057241.0]], [[4891514.549080522], [4945902.111888124], [4970691.477910499], [4987402.732554517], [5054209.304602082], [5081764.484108898], [5365168.117891555], [5613035.070200352], [5438999.45755067], [5151927.317990045], [5068233.0]], [[1761369.9330594847], [1937575.720847009], [1994414.2541500765], [2008088.3460747662], [2151509.2227061056], [2263481.6840816364], [2608442.456322934], [3006027.4705647645], [3359877.014039335], [3451977.44701845], [3585859.0]], [[3374808.480807036], [3063492.4514293275], [3085340.1944784755], [3228057.283333333], [3329916.024581181], [2607404.401737362], [3022633.689207183], [2834318.0823479616], [2038035.3522217902], [2185508.6864052652], [2637895.9999999995]], [[1273643.886982227], [1321780.249671784], [1346559.5557172026], [1444203.5450467288], [1540332.5124089143], [1576228.885821755], [1697037.7328503444], [2001801.9406197756], [2105415.0266605997], [2220838.506662407], [2378484.0]], [[847372.3785690968], [900323.438722428], [1145591.1503675345], [1089852.0765109034], [1220802.9692882146], [1038234.2657884903], [1345098.5288391002], [1513512.9918849051], [1569965.7197316415], [1523126.6448434878], [1434166.0]], [[994897.2711824445], [1052983.4525216164], [1071294.1978288242], [1169845.2274766355], [1256363.717441092], [1234889.3748407215], [1202936.3548921521], [1195483.4143629142], [1267462.9701881334], [1289419.7535877405], [1316419.0]], [[5260929.489127674], [5156984.369195341], [5075447.674401905], [2529154.426012461], [1173842.7657918644], [721077.3690684041], [988700.2594363176], [1043984.4401388472], [1052657.1742223438], [1047224.6451837604], [1250820.0]], [[696474.1078690605], [667896.8886271395], [748440.8436889569], [787331.242024922], [821645.1576772316], [716888.9687768017], [862749.3137240398], [872887.7803462683], [835204.6828897998], [813494.775956473], [881648.0]], [[148083.50050417118], [150081.68392623964], [176080.0236311043], [181323.43311526478], [183360.73735920255], [173935.1964395109], [159138.12374937587], [216263.19239708592], [207710.57654338438], [213751.09324346983], [458.0]]]

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("http://www.randalolson.com/wp-content/uploads/percent-bachelors-degrees-women-usa.csv")
# Out:
# /Users/alexwu/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/alexwu/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# %matplotlib inline
plt.figure()

# %%
ax = plt.subplot(111)
x = [21, 40, 70]
y = [1, 12, 100]
plt.plot(x,y, lw=10, color="g", )
plt.show()

# %%
majors = ['Health Professions', 'Public Administration', 'Education', 'Psychology',    
          'Foreign Languages', 'English', 'Communications\nand Journalism',    
          'Art and Performance', 'Biology', 'Agriculture',    
          'Social Sciences and History', 'Business', 'Math and Statistics',    
          'Architecture', 'Physical Sciences', 'Computer Science',    
          'Engineering']   
for column in majors:
    plt.plot(data.Year.values,
            data[column.replace("\n", " ")].values,
            lw=2.5)
