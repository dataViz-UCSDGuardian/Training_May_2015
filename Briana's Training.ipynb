# %%
import openpyxl as op
data = op.load_workbook('finance_and_giving.xlsx')
sheet1 = data.get_sheet_by_name("12.1.1")
print(sheet1.cell(row=5,column=5).value) 
print(sheet1['E5'].value)

# %%
yrs = []
yrs.append([67,34])
yrs.append([67,34])
print (yrs[1][1])
print (yrs)

# %%
empty = []
for r in range(3,13):
    empty.append([])
    for c in range(4,15):
        #empty.append(sheet1.cell(rows = r,column = c).value)
        empty[r-3].append(sheet1.cell(row=r,column=c).value)
        print(empty[r-3])
print (empty)

# %%
yrs = [1,2,3,4,5]
dates = [1990,1991,1992,1993,1994]
import matplotlib.pyplot as m
# %matplotlib inline
m.figure(figsize=(12,9))
m.subplot(111)
m.plot(yrs,dates)
